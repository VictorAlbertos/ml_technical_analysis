# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import *

from keras.models import Sequential
from keras.layers import BatchNormalization
from keras.layers.core import Dense, Dropout, Activation, Flatten

import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set()
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
symbol = 'S&P_500'
df = pd.read_csv(f'datasets/{symbol}.csv')

# %%
y = df.trading_signal
X = df.drop(['trading_signal', 'close', 'low', 'high', 'open', 'volume'], axis=1).select_dtypes(exclude=['object'])
X = (X-X.min())/(X.max()-X.min())
train_X, test_X, train_y, test_y = train_test_split(X.as_matrix(), y.as_matrix(), test_size=0.25)

# %%
model = Sequential()
model.add(Dense(32, input_shape = (test_X.shape[1], )))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(128))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(BatchNormalization())
model.add(Activation('sigmoid'))
model.compile(optimizer='adam', loss='mae')

# %%
history = model.fit(train_X, train_y, shuffle=True, batch_size=128, epochs=200, validation_data=(test_X, test_y))
# Out:
# Train on 9423 samples, validate on 3142 samples
# Epoch 1/200
# 9423/9423 [==============================] - 2s 181us/step - loss: 0.2667 - val_loss: 0.2436
# Epoch 2/200
# 9423/9423 [==============================] - 0s 34us/step - loss: 0.2484 - val_loss: 0.2355
# Epoch 3/200
# 9423/9423 [==============================] - 0s 34us/step - loss: 0.2433 - val_loss: 0.2335
# Epoch 4/200
# 9423/9423 [==============================] - 0s 34us/step - loss: 0.2409 - val_loss: 0.2310
# Epoch 5/200
# 9423/9423 [==============================] - 0s 36us/step - loss: 0.2380 - val_loss: 0.2251
# Epoch 6/200
# 9423/9423 [==============================] - 0s 39us/step - loss: 0.2353 - val_loss: 0.2219
# Epoch 7/200
# 9423/9423 [==============================] - 0s 45us/step - loss: 0.2347 - val_loss: 0.2191
# Epoch 8/200
# 9423/9423 [==============================] - 0s 40us/step - loss: 0.2336 - val_loss: 0.2189
# Epoch 9/200
# ...

# %%
prediction = model.predict(test_X)

score = model.evaluate(test_X, test_y)
print(score)

predicted = model.predict(test_X)
print(f"MAE: {mean_absolute_error(test_y, predicted)}")
# Out:
# 3142/3142 [==============================] - 0s 24us/step
# 0.21289525327600545
# MAE: 0.21289525109049293

# %%
plt.plot(history.history['val_loss'], label='val_loss')
plt.plot(history.history['loss'], label='loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
index = index
train_X, test_X, train_y, test_y = train_test_split(index, y.as_matrix(), test_size=0.25)

# %%
temp = df.iloc[test_X]

# %%
temp['prediction_trading_signal'] = prediction
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
temp
# Out:
#               open         high          low        close      volume  \
# 725     105.029999   106.250000   104.650002   105.620003    20670000
# 11148  1629.939941  1637.709961  1610.920044  1612.520020  3202550000
# 6908    660.229980   662.750000   656.830017   662.380005   347290000
# 3440    135.470001   137.929993   135.470001   137.929993    84440000
# 6278    469.809998   472.089996   467.570007   471.760010   348270000
# 3664    167.759995   170.279999   167.759995   170.279999   118270000
# 6965    702.289978   704.109985   700.530029   700.919983   367640000
# 7791   1424.969971  1435.910034  1420.630005  1424.369995  1045100000
# 3944    167.360001   167.380005   165.789993   165.970001    69790000
# 11432  1980.030029  1984.849976  1969.949951  1969.949951  3183300000
# 9583   1436.109985  1437.650024  1423.280029  1437.500000  2754660000
# 8640    983.450012   991.640015   974.859985   975.320007  1459200000
# ...
